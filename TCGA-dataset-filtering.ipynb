# %%
import pandas as pd
import os

# %%
data_file = "/Users/anb/ESCA_counts.txt"

data = pd.read_csv(
    data_file, comment="#", header=0, sep=' ', low_memory=False
)

# %%
data
# Out:
#                     TCGA-V5-A7RC-06A-11R-A406-31  \
# ENSG00000000003.15                          2747
# ENSG00000000005.6                              1
# ENSG00000000419.13                          2931
# ENSG00000000457.14                           973
# ENSG00000000460.17                           801
# ...                                          ...
# ENSG00000288669.1                              0
# ENSG00000288670.1                            484
# ENSG00000288671.1                              0
# ENSG00000288674.1                              9
# ENSG00000288675.1                             60
#
#                     TCGA-2H-A9GF-01A-11R-A37I-31  \
# ENSG00000000003.15                          2967
# ENSG00000000005.6                              0
# ENSG00000000419.13                          2563
# ENSG00000000457.14                          1229
# ENSG00000000460.17                           837
# ...                                          ...
# ...

# %%
tumor = 0
normal = 0
for i in list(list(data.columns)[1:]):
    j = i.split('-')
#     print (j[3])
    
    if ("01" in j[3]):
        tumor += 1
    else:
        normal += 1
print ("tumor = ",tumor,"\nnormal = ",normal)
# Out:
# tumor =  162
# normal =  11
